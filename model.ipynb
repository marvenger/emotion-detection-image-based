# %% [markdown]
# # Intro to the project:
#
# Using **CNN along with ResNets**, the model classifies the images of 4 different classes of human emotions, namely, ***angry, neutral, sad and happy.

# %% [markdown]
# # Importing the required librairies

# %%
import os
import torch
import torchvision
import tarfile
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets.utils import download_url
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as tt
from torch.utils.data import random_split
from torchvision.utils import make_grid
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

matplotlib.rcParams['figure.facecolor'] = '#ffffff'

# %%
project_name='05b-image_classification-resnet'

# %% [markdown]
# # Importing and splitting the data into train and test
#
# **I've used the test data for validation!**

# %%
data_dir_train = '/kaggle/input/brain-dead-emotion-detection/brain_dead_emotion_detection/Train'
data_dir_test = '/kaggle/input/brain-dead-emotion-detection/brain_dead_emotion_detection/Test'
print(os.listdir(data_dir))
# Out:
# ['angry', 'neutral', 'sad', 'happy']

# %%
# Data transforms (normalization & data augmentation)
stats = ((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
train_tfms = tt.Compose([tt.RandomCrop(64, padding=4, padding_mode='reflect'), 
                         tt.RandomHorizontalFlip(), 
                         tt.ToTensor(), 
                         tt.Normalize(*stats,inplace=True)])
valid_tfms = tt.Compose([tt.ToTensor(), tt.Normalize(*stats)])

# %%
from torchvision import datasets, transforms, models

# %%
train_transforms = transforms.Compose([transforms.Resize(64),
                                       transforms.ToTensor(),
                                       ])
test_transforms = transforms.Compose([transforms.Resize(64),
                                      transforms.ToTensor(),
                                      ])
train_data = datasets.ImageFolder(data_dir_train,       
                    transform=train_transforms)
test_data = datasets.ImageFolder(data_dir_test,
                    transform=test_transforms)

# %%
batch_size = 8

# %% [markdown]
# # Loading the data intp data loaders!

# %%
# PyTorch data loaders
train_dl = DataLoader(train_data, batch_size, shuffle=True, num_workers=2, pin_memory=True)
valid_dl = DataLoader(test_data, batch_size*2, num_workers=2, pin_memory=True)

# %%
def denormalize(images, means, stds):
    means = torch.tensor(means).reshape(1, 3, 1, 1)
    stds = torch.tensor(stds).reshape(1, 3, 1, 1)
    return images * stds + means

def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(12, 12))
        ax.set_xticks([]); ax.set_yticks([])
        denorm_images = denormalize(images, *stats)
        ax.imshow(make_grid(denorm_images[:64], nrow=8).permute(1, 2, 0).clamp(0,1))
        break

# %%
show_batch(train_dl)

# %% [markdown]
# # Using a GPU

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %% [markdown]
# We can now wrap our training and validation data loaders using `DeviceDataLoader` for automatically transferring batches of data to the GPU (if available).

# %%
train_dl = DeviceDataLoader(train_dl, device)
valid_dl = DeviceDataLoader(valid_dl, device)

# %% [markdown]
# # Simple Residual block!

# %%
class SimpleResidualBlock(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        
    def forward(self, x):
        out = self.conv1(x)
        out = self.relu1(out)
        out = self.conv2(out)
        return self.relu2(out) + x # ReLU can be applied before or after adding the input

# %%
simple_resnet = to_device(SimpleResidualBlock(), device)

for images, labels in train_dl:
    out = simple_resnet(images)
    print(out.shape)
    break
    
del simple_resnet, images, labels
torch.cuda.empty_cache()
# Out:
# torch.Size([8, 3, 64, 64])

# %% [markdown]
# # Model!

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_acc']))

# %%
def conv_block(in_channels, out_channels, pool=False):
    layers = [nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1), 
              nn.BatchNorm2d(out_channels), 
              nn.ReLU(inplace=True)]
    if pool: layers.append(nn.MaxPool2d(2))
    return nn.Sequential(*layers)

class ResNet9(ImageClassificationBase):
    def __init__(self, in_channels, num_classes):
        super().__init__()
        
        self.conv1 = conv_block(in_channels, 64)
        self.conv2 = conv_block(64, 128, pool=True)
        self.res1 = nn.Sequential(conv_block(128, 128), conv_block(128, 128))
        
        self.conv3 = conv_block(128, 256, pool=True)
        self.conv4 = conv_block(256, 512, pool=True)
        self.res2 = nn.Sequential(conv_block(512, 512), conv_block(512, 512))
        
        self.classifier = nn.Sequential(nn.AdaptiveMaxPool2d(1), 
                                        nn.Flatten(), 
                                        nn.Dropout(0.2),
                                        nn.Linear(512, num_classes))
        
    def forward(self, xb):
        out = self.conv1(xb)
        out = self.conv2(out)
        out = self.res1(out) + out
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.res2(out) + out
        out = self.classifier(out)
        return out

# %%
model = to_device(ResNet9(3, 4), device)
model
# Out:
# ResNet9(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (res1): Sequential(
#     (0): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (res2): Sequential(
#     (0): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): AdaptiveMaxPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=512, out_features=4, bias=True)
#   )
# )

# %% [markdown]
# # Training the model

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def fit_one_cycle(epochs, max_lr, model, train_loader, val_loader, 
                  weight_decay=0, grad_clip=None, opt_func=torch.optim.SGD):
    torch.cuda.empty_cache()
    history = []
    
    # Set up cutom optimizer with weight decay
    optimizer = opt_func(model.parameters(), max_lr, weight_decay=weight_decay)
    # Set up one-cycle learning rate scheduler
    sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr, epochs=epochs, 
                                                steps_per_epoch=len(train_loader))
    
    for epoch in range(epochs):
        # Training Phase 
        model.train()
        train_losses = []
        lrs = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            
            # Gradient clipping
            if grad_clip: 
                nn.utils.clip_grad_value_(model.parameters(), grad_clip)
            
            optimizer.step()
            optimizer.zero_grad()
            
            # Record & update learning rate
            lrs.append(get_lr(optimizer))
            sched.step()
        
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        result['lrs'] = lrs
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %% [markdown]
# # Evaluating the model

# %%
history = [evaluate(model, valid_dl)]
history
# Out:
# [{'val_loss': 1.3864535093307495, 'val_acc': 0.2734375}]

# %%
epochs = 500
max_lr = 0.01
grad_clip = 0.1
weight_decay = 1e-4
opt_func = torch.optim.Adam

# %% [markdown]
# # Visualizing th loss

# %%
# %%time
history = fit_one_cycle(epochs, max_lr, model, train_dl, valid_dl, 
                             grad_clip=grad_clip, 
                             weight_decay=weight_decay, 
                             opt_func=opt_func)
# Out:
# Epoch [0], last_lr: 0.00040, train_loss: 1.6006, val_loss: 1.4073, val_acc: 0.3750
# Epoch [1], last_lr: 0.00040, train_loss: 1.1890, val_loss: 1.4002, val_acc: 0.3984
# Epoch [2], last_lr: 0.00041, train_loss: 1.0409, val_loss: 1.4451, val_acc: 0.4583
# Epoch [3], last_lr: 0.00042, train_loss: 0.8622, val_loss: 1.6398, val_acc: 0.4844
# Epoch [4], last_lr: 0.00043, train_loss: 0.7184, val_loss: 1.2378, val_acc: 0.5964
# Epoch [5], last_lr: 0.00044, train_loss: 0.6504, val_loss: 1.5239, val_acc: 0.5182
# Epoch [6], last_lr: 0.00045, train_loss: 0.5179, val_loss: 1.6830, val_acc: 0.5208
# Epoch [7], last_lr: 0.00047, train_loss: 0.4991, val_loss: 1.2301, val_acc: 0.6042
# Epoch [8], last_lr: 0.00048, train_loss: 0.4020, val_loss: 1.2628, val_acc: 0.6615
# Epoch [9], last_lr: 0.00050, train_loss: 0.3741, val_loss: 1.3059, val_acc: 0.5911
# Epoch [10], last_lr: 0.00053, train_loss: 0.3836, val_loss: 1.1869, val_acc: 0.6302
# Epoch [11], last_lr: 0.00055, train_loss: 0.3028, val_loss: 1.3704, val_acc: 0.6120
# Epoch [12], last_lr: 0.00058, train_loss: 0.3603, val_loss: 1.4861, val_acc: 0.6510
# Epoch [13], last_lr: 0.00060, train_loss: 0.3008, val_loss: 1.5439, val_acc: 0.6146
# Epoch [14], last_lr: 0.00063, train_loss: 0.3059, val_loss: 1.5615, val_acc: 0.6276
# Epoch [15], last_lr: 0.00067, train_loss: 0.3024, val_loss: 1.7089, val_acc: 0.5599
# Epoch [16], last_lr: 0.00070, train_loss: 0.3646, val_loss: 1.5605, val_acc: 0.6693
# Epoch [17], last_lr: 0.00074, train_loss: 0.2442, val_loss: 1.7049, val_acc: 0.6042
# Epoch [18], last_lr: 0.00077, train_loss: 0.2784, val_loss: 1.3520, val_acc: 0.6823
# Epoch [19], last_lr: 0.00081, train_loss: 0.2257, val_loss: 1.7264, val_acc: 0.5677
# Epoch [20], last_lr: 0.00086, train_loss: 0.3201, val_loss: 1.9585, val_acc: 0.5885
# Epoch [21], last_lr: 0.00090, train_loss: 0.2817, val_loss: 1.7955, val_acc: 0.6224
# Epoch [22], last_lr: 0.00095, train_loss: 0.2342, val_loss: 1.6465, val_acc: 0.6042
# Epoch [23], last_lr: 0.00099, train_loss: 0.3201, val_loss: 1.4422, val_acc: 0.6589
# Epoch [24], last_lr: 0.00104, train_loss: 0.2863, val_loss: 2.6921, val_acc: 0.5286
# Epoch [25], last_lr: 0.00109, train_loss: 0.3445, val_loss: 1.6329, val_acc: 0.6536
# Epoch [26], last_lr: 0.00115, train_loss: 0.4145, val_loss: 1.2599, val_acc: 0.6172
# Epoch [27], last_lr: 0.00120, train_loss: 0.3521, val_loss: 2.1890, val_acc: 0.6510
# Epoch [28], last_lr: 0.00126, train_loss: 0.3597, val_loss: 1.1703, val_acc: 0.6849
# Epoch [29], last_lr: 0.00132, train_loss: 0.2334, val_loss: 1.4133, val_acc: 0.7083
# Epoch [30], last_lr: 0.00138, train_loss: 0.3177, val_loss: 1.7559, val_acc: 0.6250
# Epoch [31], last_lr: 0.00144, train_loss: 0.3335, val_loss: 1.9393, val_acc: 0.6380
# Epoch [32], last_lr: 0.00150, train_loss: 0.3502, val_loss: 1.6630, val_acc: 0.6536
# Epoch [33], last_lr: 0.00157, train_loss: 0.3320, val_loss: 2.0421, val_acc: 0.6172
# Epoch [34], last_lr: 0.00163, train_loss: 0.3266, val_loss: 1.6434, val_acc: 0.6536
# Epoch [35], last_lr: 0.00170, train_loss: 0.4635, val_loss: 2.1235, val_acc: 0.6172
# Epoch [36], last_lr: 0.00177, train_loss: 0.4235, val_loss: 2.0907, val_acc: 0.6198
# Epoch [37], last_lr: 0.00184, train_loss: 0.3610, val_loss: 2.9223, val_acc: 0.5521
# Epoch [38], last_lr: 0.00191, train_loss: 0.3115, val_loss: 2.5566, val_acc: 0.6016
# Epoch [39], last_lr: 0.00199, train_loss: 0.4182, val_loss: 1.8090, val_acc: 0.6328
# Epoch [40], last_lr: 0.00206, train_loss: 0.4510, val_loss: 1.8749, val_acc: 0.6432
# Epoch [41], last_lr: 0.00214, train_loss: 0.3367, val_loss: 1.7060, val_acc: 0.6693
# Epoch [42], last_lr: 0.00222, train_loss: 0.4902, val_loss: 1.9331, val_acc: 0.6224
# Epoch [43], last_lr: 0.00230, train_loss: 0.3330, val_loss: 2.0446, val_acc: 0.6224
# Epoch [44], last_lr: 0.00238, train_loss: 0.5055, val_loss: 1.7610, val_acc: 0.6380
# Epoch [45], last_lr: 0.00246, train_loss: 0.3036, val_loss: 1.9241, val_acc: 0.6667
# Epoch [46], last_lr: 0.00254, train_loss: 0.3261, val_loss: 2.8814, val_acc: 0.4635
# Epoch [47], last_lr: 0.00263, train_loss: 0.3631, val_loss: 2.2466, val_acc: 0.6120
# Epoch [48], last_lr: 0.00271, train_loss: 0.3799, val_loss: 2.3034, val_acc: 0.6276
# Epoch [49], last_lr: 0.00280, train_loss: 0.4643, val_loss: 1.7093, val_acc: 0.6615
# Epoch [50], last_lr: 0.00289, train_loss: 0.5809, val_loss: 1.9756, val_acc: 0.6458
# Epoch [51], last_lr: 0.00298, train_loss: 0.3494, val_loss: 2.2807, val_acc: 0.5599
# Epoch [52], last_lr: 0.00307, train_loss: 0.3632, val_loss: 1.6860, val_acc: 0.6875
# Epoch [53], last_lr: 0.00316, train_loss: 0.3412, val_loss: 1.8625, val_acc: 0.6823
# Epoch [54], last_lr: 0.00325, train_loss: 0.4672, val_loss: 1.8632, val_acc: 0.6120
# Epoch [55], last_lr: 0.00334, train_loss: 0.3453, val_loss: 2.1519, val_acc: 0.5859
# Epoch [56], last_lr: 0.00343, train_loss: 0.2728, val_loss: 1.6974, val_acc: 0.6016
# Epoch [57], last_lr: 0.00353, train_loss: 0.3287, val_loss: 2.3004, val_acc: 0.6510
# Epoch [58], last_lr: 0.00362, train_loss: 0.3246, val_loss: 1.6731, val_acc: 0.6354
# Epoch [59], last_lr: 0.00372, train_loss: 0.4080, val_loss: 2.8950, val_acc: 0.5599
# Epoch [60], last_lr: 0.00381, train_loss: 0.2948, val_loss: 1.4955, val_acc: 0.6562
# Epoch [61], last_lr: 0.00391, train_loss: 0.3869, val_loss: 2.0372, val_acc: 0.5885
# Epoch [62], last_lr: 0.00401, train_loss: 0.3412, val_loss: 1.7022, val_acc: 0.6250
# Epoch [63], last_lr: 0.00410, train_loss: 0.2573, val_loss: 2.0623, val_acc: 0.6302
# Epoch [64], last_lr: 0.00420, train_loss: 0.3498, val_loss: 2.7016, val_acc: 0.5469
# Epoch [65], last_lr: 0.00430, train_loss: 0.2954, val_loss: 1.8125, val_acc: 0.6458
# Epoch [66], last_lr: 0.00440, train_loss: 0.3194, val_loss: 2.9400, val_acc: 0.5781
# Epoch [67], last_lr: 0.00450, train_loss: 0.4186, val_loss: 2.0319, val_acc: 0.6745
# Epoch [68], last_lr: 0.00460, train_loss: 0.2357, val_loss: 3.6918, val_acc: 0.5000
# Epoch [69], last_lr: 0.00470, train_loss: 0.3174, val_loss: 1.6806, val_acc: 0.6380
# Epoch [70], last_lr: 0.00480, train_loss: 0.2870, val_loss: 1.8949, val_acc: 0.6146
# Epoch [71], last_lr: 0.00490, train_loss: 0.2615, val_loss: 2.1219, val_acc: 0.6094
# Epoch [72], last_lr: 0.00500, train_loss: 0.2624, val_loss: 2.4006, val_acc: 0.6224
# Epoch [73], last_lr: 0.00510, train_loss: 0.3321, val_loss: 2.3016, val_acc: 0.5755
# Epoch [74], last_lr: 0.00520, train_loss: 0.2537, val_loss: 1.8212, val_acc: 0.5938
# Epoch [75], last_lr: 0.00530, train_loss: 0.2849, val_loss: 1.9288, val_acc: 0.6302
# Epoch [76], last_lr: 0.00540, train_loss: 0.3453, val_loss: 1.9818, val_acc: 0.5885
# Epoch [77], last_lr: 0.00550, train_loss: 0.1817, val_loss: 2.2217, val_acc: 0.6016
# Epoch [78], last_lr: 0.00560, train_loss: 0.3318, val_loss: 2.2133, val_acc: 0.5885
# Epoch [79], last_lr: 0.00570, train_loss: 0.3368, val_loss: 1.6354, val_acc: 0.6536
# Epoch [80], last_lr: 0.00580, train_loss: 0.2827, val_loss: 2.2029, val_acc: 0.6016
# Epoch [81], last_lr: 0.00590, train_loss: 0.2454, val_loss: 1.7787, val_acc: 0.6510
# Epoch [82], last_lr: 0.00600, train_loss: 0.2472, val_loss: 1.6856, val_acc: 0.6094
# Epoch [83], last_lr: 0.00610, train_loss: 0.3525, val_loss: 1.9094, val_acc: 0.5990
# Epoch [84], last_lr: 0.00620, train_loss: 0.2132, val_loss: 2.0428, val_acc: 0.5833
# Epoch [85], last_lr: 0.00630, train_loss: 0.2747, val_loss: 2.8176, val_acc: 0.5938
# Epoch [86], last_lr: 0.00639, train_loss: 0.2330, val_loss: 3.7878, val_acc: 0.4557
# Epoch [87], last_lr: 0.00649, train_loss: 0.3909, val_loss: 2.2662, val_acc: 0.5625
# Epoch [88], last_lr: 0.00659, train_loss: 0.3173, val_loss: 1.9233, val_acc: 0.6615
# Epoch [89], last_lr: 0.00668, train_loss: 0.2854, val_loss: 1.6454, val_acc: 0.6562
# Epoch [90], last_lr: 0.00678, train_loss: 0.1987, val_loss: 1.6189, val_acc: 0.6250
# Epoch [91], last_lr: 0.00687, train_loss: 0.2530, val_loss: 2.8653, val_acc: 0.5573
# Epoch [92], last_lr: 0.00697, train_loss: 0.3154, val_loss: 2.2010, val_acc: 0.5885
# Epoch [93], last_lr: 0.00706, train_loss: 0.2656, val_loss: 1.8018, val_acc: 0.6536
# Epoch [94], last_lr: 0.00715, train_loss: 0.2245, val_loss: 2.0022, val_acc: 0.5729
# Epoch [95], last_lr: 0.00724, train_loss: 0.3507, val_loss: 2.9825, val_acc: 0.5260
# Epoch [96], last_lr: 0.00733, train_loss: 0.2715, val_loss: 2.0835, val_acc: 0.6250
# Epoch [97], last_lr: 0.00742, train_loss: 0.2545, val_loss: 1.8258, val_acc: 0.6615
# Epoch [98], last_lr: 0.00751, train_loss: 0.3369, val_loss: 2.1897, val_acc: 0.5911
# Epoch [99], last_lr: 0.00760, train_loss: 0.2975, val_loss: 2.2049, val_acc: 0.5547
# Epoch [100], last_lr: 0.00769, train_loss: 0.2362, val_loss: 1.5423, val_acc: 0.6901
# Epoch [101], last_lr: 0.00777, train_loss: 0.2654, val_loss: 4.3434, val_acc: 0.4766
# Epoch [102], last_lr: 0.00786, train_loss: 0.3350, val_loss: 1.8375, val_acc: 0.6589
# Epoch [103], last_lr: 0.00794, train_loss: 0.1975, val_loss: 1.9586, val_acc: 0.6120
# Epoch [104], last_lr: 0.00802, train_loss: 0.2152, val_loss: 2.2064, val_acc: 0.6510
# Epoch [105], last_lr: 0.00810, train_loss: 0.2908, val_loss: 2.3040, val_acc: 0.6042
# Epoch [106], last_lr: 0.00818, train_loss: 0.2800, val_loss: 2.5750, val_acc: 0.6250
# Epoch [107], last_lr: 0.00826, train_loss: 0.3394, val_loss: 2.0938, val_acc: 0.6016
# Epoch [108], last_lr: 0.00834, train_loss: 0.2603, val_loss: 3.1647, val_acc: 0.5443
# Epoch [109], last_lr: 0.00841, train_loss: 0.2796, val_loss: 1.9973, val_acc: 0.6354
# Epoch [110], last_lr: 0.00849, train_loss: 0.2529, val_loss: 1.5554, val_acc: 0.6224
# Epoch [111], last_lr: 0.00856, train_loss: 0.3427, val_loss: 1.8507, val_acc: 0.5781
# Epoch [112], last_lr: 0.00863, train_loss: 0.3302, val_loss: 1.9027, val_acc: 0.6432
# Epoch [113], last_lr: 0.00870, train_loss: 0.3151, val_loss: 1.7528, val_acc: 0.6328
# Epoch [114], last_lr: 0.00877, train_loss: 0.2091, val_loss: 4.3498, val_acc: 0.5104
# Epoch [115], last_lr: 0.00883, train_loss: 0.2884, val_loss: 2.4714, val_acc: 0.6276
# Epoch [116], last_lr: 0.00890, train_loss: 0.2443, val_loss: 1.9675, val_acc: 0.6458
# Epoch [117], last_lr: 0.00896, train_loss: 0.3126, val_loss: 1.9679, val_acc: 0.6276
# Epoch [118], last_lr: 0.00902, train_loss: 0.2678, val_loss: 2.0950, val_acc: 0.6146
# Epoch [119], last_lr: 0.00908, train_loss: 0.3274, val_loss: 1.8038, val_acc: 0.6302
# Epoch [120], last_lr: 0.00914, train_loss: 0.3372, val_loss: 2.5001, val_acc: 0.5911
# Epoch [121], last_lr: 0.00920, train_loss: 0.3358, val_loss: 4.0934, val_acc: 0.3828
# Epoch [122], last_lr: 0.00925, train_loss: 0.2786, val_loss: 2.1094, val_acc: 0.6250
# Epoch [123], last_lr: 0.00931, train_loss: 0.3110, val_loss: 2.0923, val_acc: 0.6302
# Epoch [124], last_lr: 0.00936, train_loss: 0.2467, val_loss: 2.4468, val_acc: 0.6068
# Epoch [125], last_lr: 0.00941, train_loss: 0.3340, val_loss: 3.9708, val_acc: 0.4844
# Epoch [126], last_lr: 0.00945, train_loss: 0.2689, val_loss: 1.7720, val_acc: 0.6536
# Epoch [127], last_lr: 0.00950, train_loss: 0.3411, val_loss: 2.1256, val_acc: 0.6172
# Epoch [128], last_lr: 0.00954, train_loss: 0.3300, val_loss: 4.4736, val_acc: 0.4010
# Epoch [129], last_lr: 0.00958, train_loss: 0.2944, val_loss: 2.2799, val_acc: 0.6224
# Epoch [130], last_lr: 0.00962, train_loss: 0.3460, val_loss: 2.7578, val_acc: 0.5547
# Epoch [131], last_lr: 0.00966, train_loss: 0.3080, val_loss: 1.7517, val_acc: 0.6094
# Epoch [132], last_lr: 0.00970, train_loss: 0.2825, val_loss: 2.0279, val_acc: 0.5599
# Epoch [133], last_lr: 0.00973, train_loss: 0.2384, val_loss: 2.2189, val_acc: 0.6068
# Epoch [134], last_lr: 0.00977, train_loss: 0.2074, val_loss: 2.4261, val_acc: 0.6094
# Epoch [135], last_lr: 0.00980, train_loss: 0.3763, val_loss: 1.9084, val_acc: 0.6328
# Epoch [136], last_lr: 0.00982, train_loss: 0.3219, val_loss: 2.8714, val_acc: 0.6224
# Epoch [137], last_lr: 0.00985, train_loss: 0.2442, val_loss: 2.3596, val_acc: 0.5781
# Epoch [138], last_lr: 0.00987, train_loss: 0.3765, val_loss: 2.6069, val_acc: 0.4974
# Epoch [139], last_lr: 0.00990, train_loss: 0.2543, val_loss: 2.2551, val_acc: 0.6354
# Epoch [140], last_lr: 0.00991, train_loss: 0.2018, val_loss: 2.2017, val_acc: 0.6562
# Epoch [141], last_lr: 0.00993, train_loss: 0.3356, val_loss: 1.8816, val_acc: 0.6406
# Epoch [142], last_lr: 0.00995, train_loss: 0.3016, val_loss: 1.7421, val_acc: 0.6276
# Epoch [143], last_lr: 0.00996, train_loss: 0.2019, val_loss: 2.1496, val_acc: 0.5964
# Epoch [144], last_lr: 0.00997, train_loss: 0.3460, val_loss: 3.8596, val_acc: 0.5026
# Epoch [145], last_lr: 0.00998, train_loss: 0.3683, val_loss: 2.4452, val_acc: 0.6068
# Epoch [146], last_lr: 0.00999, train_loss: 0.3352, val_loss: 2.1265, val_acc: 0.6198
# Epoch [147], last_lr: 0.01000, train_loss: 0.3658, val_loss: 1.8662, val_acc: 0.6250
# Epoch [148], last_lr: 0.01000, train_loss: 0.2703, val_loss: 2.5102, val_acc: 0.6042
# Epoch [149], last_lr: 0.01000, train_loss: 0.2498, val_loss: 2.4562, val_acc: 0.6094
# Epoch [150], last_lr: 0.01000, train_loss: 0.1906, val_loss: 2.1538, val_acc: 0.6042
# Epoch [151], last_lr: 0.01000, train_loss: 0.2186, val_loss: 2.4203, val_acc: 0.6016
# Epoch [152], last_lr: 0.01000, train_loss: 0.2620, val_loss: 2.6259, val_acc: 0.6016
# Epoch [153], last_lr: 0.01000, train_loss: 0.3292, val_loss: 2.7690, val_acc: 0.6224
# Epoch [154], last_lr: 0.00999, train_loss: 0.3853, val_loss: 3.1789, val_acc: 0.5521
# Epoch [155], last_lr: 0.00999, train_loss: 0.3643, val_loss: 2.3798, val_acc: 0.6719
# Epoch [156], last_lr: 0.00999, train_loss: 0.2822, val_loss: 2.0093, val_acc: 0.6589
# Epoch [157], last_lr: 0.00999, train_loss: 0.2501, val_loss: 2.2638, val_acc: 0.6302
# Epoch [158], last_lr: 0.00998, train_loss: 0.2776, val_loss: 2.3429, val_acc: 0.6354
# Epoch [159], last_lr: 0.00998, train_loss: 0.2091, val_loss: 2.6439, val_acc: 0.6224
# Epoch [160], last_lr: 0.00998, train_loss: 0.3281, val_loss: 2.1170, val_acc: 0.5859
# Epoch [161], last_lr: 0.00997, train_loss: 0.2694, val_loss: 1.9685, val_acc: 0.6797
# Epoch [162], last_lr: 0.00997, train_loss: 0.2291, val_loss: 2.1706, val_acc: 0.6771
# Epoch [163], last_lr: 0.00996, train_loss: 0.3326, val_loss: 2.7824, val_acc: 0.6875
# Epoch [164], last_lr: 0.00995, train_loss: 0.3513, val_loss: 2.1324, val_acc: 0.6510
# Epoch [165], last_lr: 0.00995, train_loss: 0.2390, val_loss: 2.7831, val_acc: 0.6693
# Epoch [166], last_lr: 0.00994, train_loss: 0.3381, val_loss: 2.7044, val_acc: 0.6484
# Epoch [167], last_lr: 0.00993, train_loss: 0.3617, val_loss: 2.4483, val_acc: 0.5990
# Epoch [168], last_lr: 0.00993, train_loss: 0.3001, val_loss: 2.0690, val_acc: 0.6536
# Epoch [169], last_lr: 0.00992, train_loss: 0.2255, val_loss: 2.2885, val_acc: 0.6615
# Epoch [170], last_lr: 0.00991, train_loss: 0.2661, val_loss: 1.7046, val_acc: 0.6641
# Epoch [171], last_lr: 0.00990, train_loss: 0.3060, val_loss: 2.0434, val_acc: 0.6849
# Epoch [172], last_lr: 0.00989, train_loss: 0.2383, val_loss: 2.1528, val_acc: 0.6406
# Epoch [173], last_lr: 0.00988, train_loss: 0.2744, val_loss: 2.4164, val_acc: 0.6120
# Epoch [174], last_lr: 0.00987, train_loss: 0.1890, val_loss: 1.9593, val_acc: 0.6510
# Epoch [175], last_lr: 0.00986, train_loss: 0.2501, val_loss: 2.2346, val_acc: 0.6458
# Epoch [176], last_lr: 0.00985, train_loss: 0.3199, val_loss: 1.9819, val_acc: 0.6354
# Epoch [177], last_lr: 0.00984, train_loss: 0.2569, val_loss: 2.3169, val_acc: 0.6146
# Epoch [178], last_lr: 0.00983, train_loss: 0.2875, val_loss: 2.8344, val_acc: 0.5729
# Epoch [179], last_lr: 0.00982, train_loss: 0.2895, val_loss: 1.9370, val_acc: 0.6589
# Epoch [180], last_lr: 0.00981, train_loss: 0.2081, val_loss: 1.9237, val_acc: 0.6510
# Epoch [181], last_lr: 0.00980, train_loss: 0.2255, val_loss: 2.7527, val_acc: 0.5755
# Epoch [182], last_lr: 0.00978, train_loss: 0.2451, val_loss: 2.1202, val_acc: 0.6406
# Epoch [183], last_lr: 0.00977, train_loss: 0.2227, val_loss: 2.5583, val_acc: 0.5807
# Epoch [184], last_lr: 0.00976, train_loss: 0.3235, val_loss: 2.7288, val_acc: 0.5885
# Epoch [185], last_lr: 0.00974, train_loss: 0.3049, val_loss: 2.5628, val_acc: 0.6667
# Epoch [186], last_lr: 0.00973, train_loss: 0.2581, val_loss: 2.7728, val_acc: 0.6302
# Epoch [187], last_lr: 0.00971, train_loss: 0.2657, val_loss: 1.8508, val_acc: 0.6589
# Epoch [188], last_lr: 0.00970, train_loss: 0.2415, val_loss: 2.8407, val_acc: 0.5625
# Epoch [189], last_lr: 0.00968, train_loss: 0.2392, val_loss: 2.4149, val_acc: 0.5495
# Epoch [190], last_lr: 0.00967, train_loss: 0.2338, val_loss: 2.1237, val_acc: 0.6562
# Epoch [191], last_lr: 0.00965, train_loss: 0.2031, val_loss: 1.8473, val_acc: 0.6250
# Epoch [192], last_lr: 0.00963, train_loss: 0.1903, val_loss: 2.4604, val_acc: 0.6302
# Epoch [193], last_lr: 0.00962, train_loss: 0.2333, val_loss: 2.6571, val_acc: 0.6380
# Epoch [194], last_lr: 0.00960, train_loss: 0.2684, val_loss: 3.5870, val_acc: 0.5990
# Epoch [195], last_lr: 0.00958, train_loss: 0.3665, val_loss: 2.0010, val_acc: 0.6458
# Epoch [196], last_lr: 0.00956, train_loss: 0.3139, val_loss: 2.2567, val_acc: 0.6849
# Epoch [197], last_lr: 0.00954, train_loss: 0.1825, val_loss: 2.0417, val_acc: 0.7135
# Epoch [198], last_lr: 0.00952, train_loss: 0.2832, val_loss: 3.8210, val_acc: 0.5391
# Epoch [199], last_lr: 0.00950, train_loss: 0.2342, val_loss: 2.2847, val_acc: 0.6693
# Epoch [200], last_lr: 0.00949, train_loss: 0.2868, val_loss: 2.4734, val_acc: 0.6745
# Epoch [201], last_lr: 0.00947, train_loss: 0.2551, val_loss: 2.0872, val_acc: 0.6484
# Epoch [202], last_lr: 0.00944, train_loss: 0.2860, val_loss: 2.8908, val_acc: 0.6250
# Epoch [203], last_lr: 0.00942, train_loss: 0.2429, val_loss: 3.2618, val_acc: 0.5807
# Epoch [204], last_lr: 0.00940, train_loss: 0.1640, val_loss: 2.5677, val_acc: 0.5781
# Epoch [205], last_lr: 0.00938, train_loss: 0.2574, val_loss: 3.1045, val_acc: 0.6641
# Epoch [206], last_lr: 0.00936, train_loss: 0.2179, val_loss: 2.7907, val_acc: 0.6406
# Epoch [207], last_lr: 0.00934, train_loss: 0.2387, val_loss: 1.8302, val_acc: 0.6536
# Epoch [208], last_lr: 0.00932, train_loss: 0.1965, val_loss: 2.3741, val_acc: 0.6745
# Epoch [209], last_lr: 0.00929, train_loss: 0.1770, val_loss: 3.0029, val_acc: 0.5651
# Epoch [210], last_lr: 0.00927, train_loss: 0.2089, val_loss: 2.5076, val_acc: 0.6458
# Epoch [211], last_lr: 0.00925, train_loss: 0.1556, val_loss: 2.7324, val_acc: 0.6615
# Epoch [212], last_lr: 0.00922, train_loss: 0.1936, val_loss: 2.3159, val_acc: 0.6120
# Epoch [213], last_lr: 0.00920, train_loss: 0.1797, val_loss: 2.5111, val_acc: 0.5807
# Epoch [214], last_lr: 0.00917, train_loss: 0.3267, val_loss: 1.7176, val_acc: 0.6406
# Epoch [215], last_lr: 0.00915, train_loss: 0.2230, val_loss: 1.9576, val_acc: 0.6615
# Epoch [216], last_lr: 0.00912, train_loss: 0.2372, val_loss: 2.7668, val_acc: 0.5885
# Epoch [217], last_lr: 0.00910, train_loss: 0.1625, val_loss: 2.4623, val_acc: 0.6589
# Epoch [218], last_lr: 0.00907, train_loss: 0.2378, val_loss: 2.6344, val_acc: 0.6198
# Epoch [219], last_lr: 0.00905, train_loss: 0.2767, val_loss: 2.3638, val_acc: 0.6016
# Epoch [220], last_lr: 0.00902, train_loss: 0.2774, val_loss: 2.7162, val_acc: 0.5833
# Epoch [221], last_lr: 0.00899, train_loss: 0.2157, val_loss: 2.2752, val_acc: 0.6536
# Epoch [222], last_lr: 0.00896, train_loss: 0.2384, val_loss: 3.2938, val_acc: 0.6042
# Epoch [223], last_lr: 0.00894, train_loss: 0.2218, val_loss: 2.2979, val_acc: 0.6797
# Epoch [224], last_lr: 0.00891, train_loss: 0.1900, val_loss: 31.6527, val_acc: 0.2604
# Epoch [225], last_lr: 0.00888, train_loss: 0.2668, val_loss: 2.2165, val_acc: 0.6380
# Epoch [226], last_lr: 0.00885, train_loss: 0.1746, val_loss: 1.9692, val_acc: 0.6172
# Epoch [227], last_lr: 0.00882, train_loss: 0.2322, val_loss: 2.5361, val_acc: 0.6328
# Epoch [228], last_lr: 0.00879, train_loss: 0.2088, val_loss: 4.1163, val_acc: 0.5833
# Epoch [229], last_lr: 0.00877, train_loss: 0.1522, val_loss: 2.4262, val_acc: 0.6432
# Epoch [230], last_lr: 0.00874, train_loss: 0.2172, val_loss: 2.8326, val_acc: 0.6901
# Epoch [231], last_lr: 0.00871, train_loss: 0.1554, val_loss: 3.0364, val_acc: 0.6380
# Epoch [232], last_lr: 0.00868, train_loss: 0.1761, val_loss: 2.5848, val_acc: 0.6458
# Epoch [233], last_lr: 0.00864, train_loss: 0.1828, val_loss: 2.1838, val_acc: 0.6146
# Epoch [234], last_lr: 0.00861, train_loss: 0.3217, val_loss: 1.8977, val_acc: 0.6406
# Epoch [235], last_lr: 0.00858, train_loss: 0.1381, val_loss: 2.1310, val_acc: 0.6667
# Epoch [236], last_lr: 0.00855, train_loss: 0.1730, val_loss: 2.1031, val_acc: 0.6536
# Epoch [237], last_lr: 0.00852, train_loss: 0.1980, val_loss: 2.6961, val_acc: 0.6302
# Epoch [238], last_lr: 0.00849, train_loss: 0.2312, val_loss: 2.3578, val_acc: 0.6432
# Epoch [239], last_lr: 0.00846, train_loss: 0.2335, val_loss: 2.1235, val_acc: 0.6276
# Epoch [240], last_lr: 0.00842, train_loss: 0.1685, val_loss: 2.3497, val_acc: 0.6432
# Epoch [241], last_lr: 0.00839, train_loss: 0.1720, val_loss: 3.3516, val_acc: 0.5729
# Epoch [242], last_lr: 0.00836, train_loss: 0.2550, val_loss: 2.4095, val_acc: 0.6771
# Epoch [243], last_lr: 0.00832, train_loss: 0.1526, val_loss: 2.3108, val_acc: 0.6484
# Epoch [244], last_lr: 0.00829, train_loss: 0.1697, val_loss: 3.1084, val_acc: 0.6172
# Epoch [245], last_lr: 0.00826, train_loss: 0.1951, val_loss: 2.3717, val_acc: 0.6536
# Epoch [246], last_lr: 0.00822, train_loss: 0.1543, val_loss: 2.9146, val_acc: 0.6536
# Epoch [247], last_lr: 0.00819, train_loss: 0.1465, val_loss: 2.4906, val_acc: 0.6328
# Epoch [248], last_lr: 0.00815, train_loss: 0.1042, val_loss: 2.6673, val_acc: 0.6589
# Epoch [249], last_lr: 0.00812, train_loss: 0.2139, val_loss: 2.6594, val_acc: 0.6172
# Epoch [250], last_lr: 0.00808, train_loss: 0.2179, val_loss: 3.0431, val_acc: 0.5859
# Epoch [251], last_lr: 0.00805, train_loss: 0.2364, val_loss: 2.6026, val_acc: 0.6302
# Epoch [252], last_lr: 0.00801, train_loss: 0.1617, val_loss: 2.3937, val_acc: 0.6719
# Epoch [253], last_lr: 0.00798, train_loss: 0.2230, val_loss: 2.7775, val_acc: 0.6042
# Epoch [254], last_lr: 0.00794, train_loss: 0.1697, val_loss: 1.9028, val_acc: 0.6615
# Epoch [255], last_lr: 0.00790, train_loss: 0.1399, val_loss: 2.2171, val_acc: 0.6328
# Epoch [256], last_lr: 0.00787, train_loss: 0.1235, val_loss: 2.0162, val_acc: 0.6641
# Epoch [257], last_lr: 0.00783, train_loss: 0.1597, val_loss: 2.2674, val_acc: 0.5755
# Epoch [258], last_lr: 0.00779, train_loss: 0.1562, val_loss: 2.0349, val_acc: 0.7135
# Epoch [259], last_lr: 0.00775, train_loss: 0.1635, val_loss: 2.1166, val_acc: 0.6484
# Epoch [260], last_lr: 0.00772, train_loss: 0.1680, val_loss: 2.6282, val_acc: 0.6172
# Epoch [261], last_lr: 0.00768, train_loss: 0.1643, val_loss: 2.1842, val_acc: 0.6198
# Epoch [262], last_lr: 0.00764, train_loss: 0.2082, val_loss: 2.1873, val_acc: 0.6302
# Epoch [263], last_lr: 0.00760, train_loss: 0.1267, val_loss: 2.5539, val_acc: 0.6380
# Epoch [264], last_lr: 0.00756, train_loss: 0.1295, val_loss: 2.3253, val_acc: 0.6458
# Epoch [265], last_lr: 0.00753, train_loss: 0.1363, val_loss: 2.2428, val_acc: 0.6146
# Epoch [266], last_lr: 0.00749, train_loss: 0.2004, val_loss: 2.5942, val_acc: 0.6406
# Epoch [267], last_lr: 0.00745, train_loss: 0.1742, val_loss: 2.7527, val_acc: 0.6120
# Epoch [268], last_lr: 0.00741, train_loss: 0.1988, val_loss: 3.4451, val_acc: 0.5312
# Epoch [269], last_lr: 0.00737, train_loss: 0.1510, val_loss: 2.2759, val_acc: 0.6406
# Epoch [270], last_lr: 0.00733, train_loss: 0.1320, val_loss: 5.2274, val_acc: 0.5391
# Epoch [271], last_lr: 0.00729, train_loss: 0.1563, val_loss: 2.7387, val_acc: 0.6380
# Epoch [272], last_lr: 0.00725, train_loss: 0.1786, val_loss: 2.1812, val_acc: 0.6380
# Epoch [273], last_lr: 0.00721, train_loss: 0.1516, val_loss: 1.9199, val_acc: 0.6484
# Epoch [274], last_lr: 0.00717, train_loss: 0.1166, val_loss: 1.9203, val_acc: 0.6276
# Epoch [275], last_lr: 0.00713, train_loss: 0.1230, val_loss: 2.2179, val_acc: 0.5833
# Epoch [276], last_lr: 0.00709, train_loss: 0.1238, val_loss: 2.3832, val_acc: 0.6328
# Epoch [277], last_lr: 0.00705, train_loss: 0.1227, val_loss: 2.5556, val_acc: 0.6016
# Epoch [278], last_lr: 0.00701, train_loss: 0.1524, val_loss: 2.3464, val_acc: 0.6510
# Epoch [279], last_lr: 0.00697, train_loss: 0.1296, val_loss: 2.1435, val_acc: 0.6250
# Epoch [280], last_lr: 0.00692, train_loss: 0.1359, val_loss: 2.2789, val_acc: 0.6198
# Epoch [281], last_lr: 0.00688, train_loss: 0.1655, val_loss: 1.8479, val_acc: 0.6771
# Epoch [282], last_lr: 0.00684, train_loss: 0.1777, val_loss: 2.9816, val_acc: 0.6250
# Epoch [283], last_lr: 0.00680, train_loss: 0.1295, val_loss: 2.6823, val_acc: 0.6510
# Epoch [284], last_lr: 0.00676, train_loss: 0.1599, val_loss: 2.1247, val_acc: 0.6745
# Epoch [285], last_lr: 0.00671, train_loss: 0.1493, val_loss: 2.5353, val_acc: 0.6328
# Epoch [286], last_lr: 0.00667, train_loss: 0.1167, val_loss: 2.7373, val_acc: 0.5938
# Epoch [287], last_lr: 0.00663, train_loss: 0.1073, val_loss: 2.4647, val_acc: 0.6484
# Epoch [288], last_lr: 0.00659, train_loss: 0.1504, val_loss: 2.2204, val_acc: 0.6615
# Epoch [289], last_lr: 0.00655, train_loss: 0.1018, val_loss: 2.3473, val_acc: 0.6458
# Epoch [290], last_lr: 0.00650, train_loss: 0.0843, val_loss: 2.4850, val_acc: 0.6589
# Epoch [291], last_lr: 0.00646, train_loss: 0.1069, val_loss: 1.9144, val_acc: 0.6094
# Epoch [292], last_lr: 0.00642, train_loss: 0.1396, val_loss: 2.2498, val_acc: 0.6016
# Epoch [293], last_lr: 0.00637, train_loss: 0.1379, val_loss: 2.2738, val_acc: 0.6198
# Epoch [294], last_lr: 0.00633, train_loss: 0.1368, val_loss: 2.7575, val_acc: 0.6094
# Epoch [295], last_lr: 0.00629, train_loss: 0.0857, val_loss: 2.4957, val_acc: 0.6510
# Epoch [296], last_lr: 0.00624, train_loss: 0.0969, val_loss: 2.7282, val_acc: 0.6510
# Epoch [297], last_lr: 0.00620, train_loss: 0.1133, val_loss: 2.3637, val_acc: 0.6120
# Epoch [298], last_lr: 0.00616, train_loss: 0.1176, val_loss: 2.0804, val_acc: 0.6302
# Epoch [299], last_lr: 0.00611, train_loss: 0.1082, val_loss: 2.4051, val_acc: 0.6484
# Epoch [300], last_lr: 0.00607, train_loss: 0.1772, val_loss: 1.8718, val_acc: 0.6719
# Epoch [301], last_lr: 0.00602, train_loss: 0.1581, val_loss: 2.3574, val_acc: 0.6536
# Epoch [302], last_lr: 0.00598, train_loss: 0.0951, val_loss: 2.4083, val_acc: 0.6849
# Epoch [303], last_lr: 0.00594, train_loss: 0.0999, val_loss: 2.1215, val_acc: 0.6432
# Epoch [304], last_lr: 0.00589, train_loss: 0.0810, val_loss: 2.0418, val_acc: 0.6328
# Epoch [305], last_lr: 0.00585, train_loss: 0.0815, val_loss: 2.3162, val_acc: 0.6146
# Epoch [306], last_lr: 0.00580, train_loss: 0.1423, val_loss: 2.5656, val_acc: 0.5938
# Epoch [307], last_lr: 0.00576, train_loss: 0.1241, val_loss: 2.9694, val_acc: 0.6302
# Epoch [308], last_lr: 0.00572, train_loss: 0.1393, val_loss: 2.2720, val_acc: 0.6641
# Epoch [309], last_lr: 0.00567, train_loss: 0.1507, val_loss: 2.3473, val_acc: 0.6302
# Epoch [310], last_lr: 0.00563, train_loss: 0.0895, val_loss: 2.7690, val_acc: 0.6068
# Epoch [311], last_lr: 0.00558, train_loss: 0.0830, val_loss: 2.6896, val_acc: 0.6146
# Epoch [312], last_lr: 0.00554, train_loss: 0.1016, val_loss: 2.3304, val_acc: 0.6172
# Epoch [313], last_lr: 0.00549, train_loss: 0.0901, val_loss: 2.2078, val_acc: 0.6562
# Epoch [314], last_lr: 0.00545, train_loss: 0.0653, val_loss: 1.9679, val_acc: 0.6693
# Epoch [315], last_lr: 0.00540, train_loss: 0.1322, val_loss: 2.3207, val_acc: 0.6510
# Epoch [316], last_lr: 0.00536, train_loss: 0.1039, val_loss: 2.1583, val_acc: 0.6458
# Epoch [317], last_lr: 0.00531, train_loss: 0.0813, val_loss: 2.2408, val_acc: 0.6823
# Epoch [318], last_lr: 0.00527, train_loss: 0.0901, val_loss: 2.4828, val_acc: 0.6615
# Epoch [319], last_lr: 0.00522, train_loss: 0.0706, val_loss: 2.4107, val_acc: 0.6615
# Epoch [320], last_lr: 0.00518, train_loss: 0.0957, val_loss: 2.7893, val_acc: 0.6172
# Epoch [321], last_lr: 0.00513, train_loss: 0.0776, val_loss: 2.3256, val_acc: 0.6771
# Epoch [322], last_lr: 0.00509, train_loss: 0.0976, val_loss: 2.6882, val_acc: 0.6354
# Epoch [323], last_lr: 0.00504, train_loss: 0.0982, val_loss: 2.4125, val_acc: 0.6302
# Epoch [324], last_lr: 0.00500, train_loss: 0.0791, val_loss: 2.3262, val_acc: 0.6771
# Epoch [325], last_lr: 0.00496, train_loss: 0.0953, val_loss: 2.3752, val_acc: 0.6302
# Epoch [326], last_lr: 0.00491, train_loss: 0.0916, val_loss: 1.8858, val_acc: 0.6823
# Epoch [327], last_lr: 0.00487, train_loss: 0.0943, val_loss: 2.4864, val_acc: 0.6276
# Epoch [328], last_lr: 0.00482, train_loss: 0.0852, val_loss: 2.1128, val_acc: 0.6849
# Epoch [329], last_lr: 0.00478, train_loss: 0.0609, val_loss: 2.5278, val_acc: 0.6771
# Epoch [330], last_lr: 0.00473, train_loss: 0.0458, val_loss: 2.0267, val_acc: 0.6510
# Epoch [331], last_lr: 0.00469, train_loss: 0.0870, val_loss: 2.2551, val_acc: 0.6927
# Epoch [332], last_lr: 0.00464, train_loss: 0.0662, val_loss: 2.2884, val_acc: 0.6380
# Epoch [333], last_lr: 0.00460, train_loss: 0.0658, val_loss: 2.5075, val_acc: 0.6615
# Epoch [334], last_lr: 0.00455, train_loss: 0.0496, val_loss: 2.1217, val_acc: 0.6380
# Epoch [335], last_lr: 0.00451, train_loss: 0.0577, val_loss: 3.1041, val_acc: 0.6354
# Epoch [336], last_lr: 0.00446, train_loss: 0.0743, val_loss: 2.4251, val_acc: 0.6536
# Epoch [337], last_lr: 0.00442, train_loss: 0.0769, val_loss: 2.5024, val_acc: 0.5911
# Epoch [338], last_lr: 0.00437, train_loss: 0.0704, val_loss: 2.7169, val_acc: 0.6120
# Epoch [339], last_lr: 0.00433, train_loss: 0.0679, val_loss: 2.5099, val_acc: 0.6276
# Epoch [340], last_lr: 0.00428, train_loss: 0.0897, val_loss: 2.3608, val_acc: 0.6536
# Epoch [341], last_lr: 0.00424, train_loss: 0.0527, val_loss: 2.4407, val_acc: 0.6615
# Epoch [342], last_lr: 0.00420, train_loss: 0.0871, val_loss: 3.1199, val_acc: 0.6016
# Epoch [343], last_lr: 0.00415, train_loss: 0.1061, val_loss: 2.2630, val_acc: 0.6510
# Epoch [344], last_lr: 0.00411, train_loss: 0.0523, val_loss: 1.9126, val_acc: 0.6589
# Epoch [345], last_lr: 0.00406, train_loss: 0.0479, val_loss: 2.3449, val_acc: 0.6745
# Epoch [346], last_lr: 0.00402, train_loss: 0.0647, val_loss: 2.0854, val_acc: 0.6797
# Epoch [347], last_lr: 0.00398, train_loss: 0.0627, val_loss: 2.2608, val_acc: 0.6641
# Epoch [348], last_lr: 0.00393, train_loss: 0.0571, val_loss: 2.4998, val_acc: 0.6146
# Epoch [349], last_lr: 0.00389, train_loss: 0.0584, val_loss: 2.3023, val_acc: 0.6484
# Epoch [350], last_lr: 0.00384, train_loss: 0.0409, val_loss: 2.5608, val_acc: 0.6484
# Epoch [351], last_lr: 0.00380, train_loss: 0.0746, val_loss: 2.2361, val_acc: 0.6693
# Epoch [352], last_lr: 0.00376, train_loss: 0.0537, val_loss: 2.2629, val_acc: 0.6797
# Epoch [353], last_lr: 0.00371, train_loss: 0.0359, val_loss: 2.2887, val_acc: 0.6771
# Epoch [354], last_lr: 0.00367, train_loss: 0.0584, val_loss: 2.6634, val_acc: 0.6745
# Epoch [355], last_lr: 0.00363, train_loss: 0.0976, val_loss: 2.2589, val_acc: 0.6458
# Epoch [356], last_lr: 0.00358, train_loss: 0.0826, val_loss: 2.0935, val_acc: 0.6510
# Epoch [357], last_lr: 0.00354, train_loss: 0.0384, val_loss: 2.2374, val_acc: 0.6953
# Epoch [358], last_lr: 0.00350, train_loss: 0.0346, val_loss: 2.2990, val_acc: 0.6849
# Epoch [359], last_lr: 0.00345, train_loss: 0.0747, val_loss: 2.4533, val_acc: 0.6875
# Epoch [360], last_lr: 0.00341, train_loss: 0.0516, val_loss: 2.3142, val_acc: 0.6771
# Epoch [361], last_lr: 0.00337, train_loss: 0.0572, val_loss: 1.8464, val_acc: 0.7057
# Epoch [362], last_lr: 0.00333, train_loss: 0.0573, val_loss: 2.2503, val_acc: 0.6797
# Epoch [363], last_lr: 0.00329, train_loss: 0.0514, val_loss: 2.4444, val_acc: 0.6771
# Epoch [364], last_lr: 0.00324, train_loss: 0.0648, val_loss: 1.9072, val_acc: 0.6797
# Epoch [365], last_lr: 0.00320, train_loss: 0.0580, val_loss: 2.1014, val_acc: 0.6953
# Epoch [366], last_lr: 0.00316, train_loss: 0.0646, val_loss: 2.0489, val_acc: 0.6589
# Epoch [367], last_lr: 0.00312, train_loss: 0.0366, val_loss: 2.1231, val_acc: 0.6771
# Epoch [368], last_lr: 0.00308, train_loss: 0.0362, val_loss: 2.1352, val_acc: 0.7031
# Epoch [369], last_lr: 0.00303, train_loss: 0.0346, val_loss: 2.3995, val_acc: 0.6667
# Epoch [370], last_lr: 0.00299, train_loss: 0.0337, val_loss: 2.3467, val_acc: 0.6562
# Epoch [371], last_lr: 0.00295, train_loss: 0.0232, val_loss: 2.3701, val_acc: 0.6693
# Epoch [372], last_lr: 0.00291, train_loss: 0.0307, val_loss: 2.4000, val_acc: 0.6693
# Epoch [373], last_lr: 0.00287, train_loss: 0.0477, val_loss: 2.3842, val_acc: 0.6484
# Epoch [374], last_lr: 0.00283, train_loss: 0.0368, val_loss: 2.6155, val_acc: 0.6224
# Epoch [375], last_lr: 0.00279, train_loss: 0.0568, val_loss: 1.8683, val_acc: 0.6927
# Epoch [376], last_lr: 0.00275, train_loss: 0.0339, val_loss: 2.1439, val_acc: 0.6745
# Epoch [377], last_lr: 0.00271, train_loss: 0.0495, val_loss: 2.4773, val_acc: 0.6484
# Epoch [378], last_lr: 0.00267, train_loss: 0.0623, val_loss: 2.1745, val_acc: 0.6276
# Epoch [379], last_lr: 0.00263, train_loss: 0.0559, val_loss: 2.1076, val_acc: 0.6875
# Epoch [380], last_lr: 0.00259, train_loss: 0.0373, val_loss: 2.1706, val_acc: 0.6693
# Epoch [381], last_lr: 0.00255, train_loss: 0.0266, val_loss: 2.1991, val_acc: 0.7005
# Epoch [382], last_lr: 0.00251, train_loss: 0.0245, val_loss: 2.6857, val_acc: 0.6536
# Epoch [383], last_lr: 0.00247, train_loss: 0.0415, val_loss: 2.5159, val_acc: 0.6484
# Epoch [384], last_lr: 0.00244, train_loss: 0.0263, val_loss: 2.7260, val_acc: 0.6562
# Epoch [385], last_lr: 0.00240, train_loss: 0.0355, val_loss: 2.2907, val_acc: 0.6536
# Epoch [386], last_lr: 0.00236, train_loss: 0.0341, val_loss: 2.0799, val_acc: 0.6615
# Epoch [387], last_lr: 0.00232, train_loss: 0.0382, val_loss: 2.1729, val_acc: 0.6484
# Epoch [388], last_lr: 0.00228, train_loss: 0.0334, val_loss: 3.3607, val_acc: 0.6432
# Epoch [389], last_lr: 0.00225, train_loss: 0.0361, val_loss: 2.6443, val_acc: 0.6589
# Epoch [390], last_lr: 0.00221, train_loss: 0.0646, val_loss: 2.3102, val_acc: 0.6250
# Epoch [391], last_lr: 0.00217, train_loss: 0.0405, val_loss: 2.1127, val_acc: 0.6536
# Epoch [392], last_lr: 0.00213, train_loss: 0.0319, val_loss: 2.4722, val_acc: 0.6719
# Epoch [393], last_lr: 0.00210, train_loss: 0.0276, val_loss: 2.3042, val_acc: 0.6719
# Epoch [394], last_lr: 0.00206, train_loss: 0.0246, val_loss: 2.2823, val_acc: 0.6849
# Epoch [395], last_lr: 0.00202, train_loss: 0.0246, val_loss: 2.2952, val_acc: 0.6458
# Epoch [396], last_lr: 0.00199, train_loss: 0.0310, val_loss: 2.1256, val_acc: 0.6536
# Epoch [397], last_lr: 0.00195, train_loss: 0.0221, val_loss: 2.7022, val_acc: 0.6536
# Epoch [398], last_lr: 0.00192, train_loss: 0.0193, val_loss: 2.2548, val_acc: 0.6693
# Epoch [399], last_lr: 0.00188, train_loss: 0.0210, val_loss: 2.1569, val_acc: 0.7083
# Epoch [400], last_lr: 0.00185, train_loss: 0.0254, val_loss: 2.3484, val_acc: 0.6771
# Epoch [401], last_lr: 0.00181, train_loss: 0.0381, val_loss: 2.1608, val_acc: 0.6510
# Epoch [402], last_lr: 0.00178, train_loss: 0.0264, val_loss: 2.3107, val_acc: 0.6536
# Epoch [403], last_lr: 0.00174, train_loss: 0.0297, val_loss: 2.4270, val_acc: 0.6667
# Epoch [404], last_lr: 0.00171, train_loss: 0.0229, val_loss: 2.2528, val_acc: 0.6432
# Epoch [405], last_lr: 0.00168, train_loss: 0.0247, val_loss: 2.4912, val_acc: 0.6510
# Epoch [406], last_lr: 0.00164, train_loss: 0.0276, val_loss: 2.3057, val_acc: 0.6484
# Epoch [407], last_lr: 0.00161, train_loss: 0.0247, val_loss: 2.3967, val_acc: 0.6510
# Epoch [408], last_lr: 0.00158, train_loss: 0.0192, val_loss: 2.3002, val_acc: 0.6615
# Epoch [409], last_lr: 0.00154, train_loss: 0.0166, val_loss: 2.4161, val_acc: 0.7031
# Epoch [410], last_lr: 0.00151, train_loss: 0.0180, val_loss: 2.5324, val_acc: 0.6589
# Epoch [411], last_lr: 0.00148, train_loss: 0.0293, val_loss: 2.3119, val_acc: 0.6927
# Epoch [412], last_lr: 0.00145, train_loss: 0.0255, val_loss: 2.3374, val_acc: 0.6458
# Epoch [413], last_lr: 0.00142, train_loss: 0.0263, val_loss: 2.4698, val_acc: 0.6276
# Epoch [414], last_lr: 0.00139, train_loss: 0.0181, val_loss: 2.5349, val_acc: 0.6641
# Epoch [415], last_lr: 0.00136, train_loss: 0.0161, val_loss: 2.6585, val_acc: 0.6589
# Epoch [416], last_lr: 0.00132, train_loss: 0.0246, val_loss: 2.6769, val_acc: 0.6458
# Epoch [417], last_lr: 0.00129, train_loss: 0.0264, val_loss: 2.1828, val_acc: 0.6979
# Epoch [418], last_lr: 0.00126, train_loss: 0.0237, val_loss: 2.5742, val_acc: 0.6979
# Epoch [419], last_lr: 0.00123, train_loss: 0.0224, val_loss: 2.2485, val_acc: 0.6562
# Epoch [420], last_lr: 0.00121, train_loss: 0.0196, val_loss: 2.4308, val_acc: 0.6797
# Epoch [421], last_lr: 0.00118, train_loss: 0.0204, val_loss: 2.5919, val_acc: 0.6536
# Epoch [422], last_lr: 0.00115, train_loss: 0.0230, val_loss: 2.2954, val_acc: 0.6667
# Epoch [423], last_lr: 0.00112, train_loss: 0.0219, val_loss: 2.5033, val_acc: 0.6484
# Epoch [424], last_lr: 0.00109, train_loss: 0.0194, val_loss: 2.4546, val_acc: 0.6615
# Epoch [425], last_lr: 0.00106, train_loss: 0.0206, val_loss: 2.4116, val_acc: 0.6562
# Epoch [426], last_lr: 0.00104, train_loss: 0.0196, val_loss: 2.5268, val_acc: 0.6589
# Epoch [427], last_lr: 0.00101, train_loss: 0.0217, val_loss: 2.5255, val_acc: 0.6745
# Epoch [428], last_lr: 0.00098, train_loss: 0.0134, val_loss: 2.3622, val_acc: 0.6719
# Epoch [429], last_lr: 0.00095, train_loss: 0.0224, val_loss: 2.4999, val_acc: 0.6589
# Epoch [430], last_lr: 0.00093, train_loss: 0.0174, val_loss: 2.6286, val_acc: 0.6484
# Epoch [431], last_lr: 0.00090, train_loss: 0.0203, val_loss: 2.5319, val_acc: 0.6224
# Epoch [432], last_lr: 0.00088, train_loss: 0.0163, val_loss: 2.5360, val_acc: 0.6484
# Epoch [433], last_lr: 0.00085, train_loss: 0.0231, val_loss: 2.5760, val_acc: 0.6667
# Epoch [434], last_lr: 0.00083, train_loss: 0.0199, val_loss: 2.4037, val_acc: 0.6615
# Epoch [435], last_lr: 0.00080, train_loss: 0.0184, val_loss: 2.3650, val_acc: 0.6641
# Epoch [436], last_lr: 0.00078, train_loss: 0.0132, val_loss: 2.3717, val_acc: 0.6719
# Epoch [437], last_lr: 0.00075, train_loss: 0.0146, val_loss: 2.3543, val_acc: 0.6536
# Epoch [438], last_lr: 0.00073, train_loss: 0.0172, val_loss: 2.4568, val_acc: 0.6667
# Epoch [439], last_lr: 0.00071, train_loss: 0.0207, val_loss: 2.5103, val_acc: 0.6745
# Epoch [440], last_lr: 0.00068, train_loss: 0.0213, val_loss: 2.3378, val_acc: 0.6641
# Epoch [441], last_lr: 0.00066, train_loss: 0.0151, val_loss: 2.4026, val_acc: 0.6719
# Epoch [442], last_lr: 0.00064, train_loss: 0.0153, val_loss: 2.4175, val_acc: 0.6641
# Epoch [443], last_lr: 0.00062, train_loss: 0.0146, val_loss: 2.2775, val_acc: 0.6641
# Epoch [444], last_lr: 0.00060, train_loss: 0.0115, val_loss: 2.3433, val_acc: 0.6823
# Epoch [445], last_lr: 0.00058, train_loss: 0.0122, val_loss: 2.3026, val_acc: 0.6771
# Epoch [446], last_lr: 0.00056, train_loss: 0.0173, val_loss: 2.3883, val_acc: 0.6641
# Epoch [447], last_lr: 0.00053, train_loss: 0.0118, val_loss: 2.4488, val_acc: 0.6693
# Epoch [448], last_lr: 0.00051, train_loss: 0.0141, val_loss: 2.5871, val_acc: 0.6484
# Epoch [449], last_lr: 0.00050, train_loss: 0.0157, val_loss: 2.5176, val_acc: 0.6510
# Epoch [450], last_lr: 0.00048, train_loss: 0.0153, val_loss: 2.5412, val_acc: 0.6536
# Epoch [451], last_lr: 0.00046, train_loss: 0.0152, val_loss: 2.4398, val_acc: 0.6536
# Epoch [452], last_lr: 0.00044, train_loss: 0.0127, val_loss: 2.4733, val_acc: 0.6458
# Epoch [453], last_lr: 0.00042, train_loss: 0.0116, val_loss: 2.4585, val_acc: 0.6536
# Epoch [454], last_lr: 0.00040, train_loss: 0.0129, val_loss: 2.5297, val_acc: 0.6406
# Epoch [455], last_lr: 0.00038, train_loss: 0.0130, val_loss: 2.4480, val_acc: 0.6536
# Epoch [456], last_lr: 0.00037, train_loss: 0.0137, val_loss: 2.5597, val_acc: 0.6224
# Epoch [457], last_lr: 0.00035, train_loss: 0.0142, val_loss: 2.5245, val_acc: 0.6562
# Epoch [458], last_lr: 0.00033, train_loss: 0.0128, val_loss: 2.5124, val_acc: 0.6562
# Epoch [459], last_lr: 0.00032, train_loss: 0.0144, val_loss: 2.6116, val_acc: 0.6562
# Epoch [460], last_lr: 0.00030, train_loss: 0.0150, val_loss: 2.3835, val_acc: 0.6589
# Epoch [461], last_lr: 0.00029, train_loss: 0.0135, val_loss: 2.3221, val_acc: 0.6615
# Epoch [462], last_lr: 0.00027, train_loss: 0.0139, val_loss: 2.3731, val_acc: 0.6562
# Epoch [463], last_lr: 0.00026, train_loss: 0.0149, val_loss: 2.4821, val_acc: 0.6615
# Epoch [464], last_lr: 0.00024, train_loss: 0.0133, val_loss: 2.5248, val_acc: 0.6510
# Epoch [465], last_lr: 0.00023, train_loss: 0.0101, val_loss: 2.5675, val_acc: 0.6562
# Epoch [466], last_lr: 0.00022, train_loss: 0.0112, val_loss: 2.4096, val_acc: 0.6536
# Epoch [467], last_lr: 0.00020, train_loss: 0.0148, val_loss: 2.4101, val_acc: 0.6536
# Epoch [468], last_lr: 0.00019, train_loss: 0.0151, val_loss: 2.3499, val_acc: 0.6615
# Epoch [469], last_lr: 0.00018, train_loss: 0.0129, val_loss: 2.4308, val_acc: 0.6667
# Epoch [470], last_lr: 0.00017, train_loss: 0.0129, val_loss: 2.5040, val_acc: 0.6615
# Epoch [471], last_lr: 0.00016, train_loss: 0.0121, val_loss: 2.4037, val_acc: 0.6536
# Epoch [472], last_lr: 0.00015, train_loss: 0.0125, val_loss: 2.4245, val_acc: 0.6667
# Epoch [473], last_lr: 0.00014, train_loss: 0.0123, val_loss: 2.6195, val_acc: 0.6562
# Epoch [474], last_lr: 0.00013, train_loss: 0.0124, val_loss: 2.5580, val_acc: 0.6536
# Epoch [475], last_lr: 0.00012, train_loss: 0.0121, val_loss: 2.4930, val_acc: 0.6484
# Epoch [476], last_lr: 0.00011, train_loss: 0.0124, val_loss: 2.4994, val_acc: 0.6432
# Epoch [477], last_lr: 0.00010, train_loss: 0.0153, val_loss: 2.5044, val_acc: 0.6589
# Epoch [478], last_lr: 0.00009, train_loss: 0.0104, val_loss: 2.4726, val_acc: 0.6589
# Epoch [479], last_lr: 0.00008, train_loss: 0.0115, val_loss: 2.4537, val_acc: 0.6589
# Epoch [480], last_lr: 0.00007, train_loss: 0.0121, val_loss: 2.4807, val_acc: 0.6536
# Epoch [481], last_lr: 0.00007, train_loss: 0.0120, val_loss: 2.5519, val_acc: 0.6615
# Epoch [482], last_lr: 0.00006, train_loss: 0.0112, val_loss: 2.4899, val_acc: 0.6562
# Epoch [483], last_lr: 0.00005, train_loss: 0.0117, val_loss: 2.5426, val_acc: 0.6562
# Epoch [484], last_lr: 0.00005, train_loss: 0.0126, val_loss: 2.4535, val_acc: 0.6510
# Epoch [485], last_lr: 0.00004, train_loss: 0.0117, val_loss: 2.5036, val_acc: 0.6562
# Epoch [486], last_lr: 0.00003, train_loss: 0.0112, val_loss: 2.4277, val_acc: 0.6562
# Epoch [487], last_lr: 0.00003, train_loss: 0.0115, val_loss: 2.5157, val_acc: 0.6562
# Epoch [488], last_lr: 0.00002, train_loss: 0.0161, val_loss: 2.4566, val_acc: 0.6667
# Epoch [489], last_lr: 0.00002, train_loss: 0.0120, val_loss: 2.5001, val_acc: 0.6589
# Epoch [490], last_lr: 0.00002, train_loss: 0.0122, val_loss: 2.4787, val_acc: 0.6536
# Epoch [491], last_lr: 0.00001, train_loss: 0.0111, val_loss: 2.5164, val_acc: 0.6667
# Epoch [492], last_lr: 0.00001, train_loss: 0.0118, val_loss: 2.4221, val_acc: 0.6615
# Epoch [493], last_lr: 0.00001, train_loss: 0.0109, val_loss: 2.4598, val_acc: 0.6589
# Epoch [494], last_lr: 0.00001, train_loss: 0.0096, val_loss: 2.4809, val_acc: 0.6562
# Epoch [495], last_lr: 0.00000, train_loss: 0.0110, val_loss: 2.5011, val_acc: 0.6562
# Epoch [496], last_lr: 0.00000, train_loss: 0.0121, val_loss: 2.4588, val_acc: 0.6484
# Epoch [497], last_lr: 0.00000, train_loss: 0.0108, val_loss: 2.4770, val_acc: 0.6562
# Epoch [498], last_lr: 0.00000, train_loss: 0.0112, val_loss: 2.4321, val_acc: 0.6589
# Epoch [499], last_lr: 0.00000, train_loss: 0.0121, val_loss: 2.5029, val_acc: 0.6562
# CPU times: user 50min 33s, sys: 20min 8s, total: 1h 10min 42s
# Wall time: 1h 19min 31s

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title(' Validation Accuracy vs. No. of epochs');

# %%
plot_accuracies(history)

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');

# %%
plot_losses(history)

# %%
def plot_lrs(history):
    lrs = np.concatenate([x.get('lrs', []) for x in history])
    plt.plot(lrs)
    plt.xlabel('Batch no.')
    plt.ylabel('Learning rate')
    plt.title('Learning Rate vs. Batch no.');

# %%
plot_lrs(history)

# %% [markdown]
# ## Testing with individual images

# %%
def predict_image(img, model):
    # Convert to a batch of 1
    xb = to_device(img.unsqueeze(0), device)
    # Get predictions from model
    yb = model(xb)
    # Pick index with highest probability
    _, preds  = torch.max(yb, dim=1)
    # Retrieve the class label
    return train_data.classes[preds[0].item()]

# %%
img, label = test_data[0]
plt.imshow(img.permute(1, 2, 0).clamp(0, 1))
print('Label:', train_data.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Label: angry , Predicted: angry

# %% [markdown]
# # An accuracy of 72%!
